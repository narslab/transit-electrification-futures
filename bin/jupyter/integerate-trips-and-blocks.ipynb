# %%
import pandas as pd

# %%
# Read dataframes of all-CDB, all-HEB, and all BEB with runs included
df_CDB = pd.read_csv(r'../../results/computed-fuel-rates-runs-all-CDB.csv', low_memory=False)
df_HEB = pd.read_csv(r'../../results/computed-fuel-rates-runs-all-HEB.csv', low_memory=False)
df_BEB = pd.read_csv(r'../../results/computed-fuel-rates-runs-all-BEB.csv', low_memory=False)

# %%
# Read dataframes of all-CDB, all-HEB, and all BEB with runs included
df_CDB = pd.read_csv(r'../../results/computed-fuel-rates-runs-all-CDB.csv', low_memory=False)
df_HEB = pd.read_csv(r'../../results/computed-fuel-rates-runs-all-HEB.csv', low_memory=False)
df_BEB = pd.read_csv(r'../../results/computed-fuel-rates-runs-all-BEB.csv', low_memory=False)

# %%
df_CDB.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'ServiceDateTime', 'DateKey',
#        'CalendarDate', 'Year', 'Month', 'OpKey', 'Operator', 'RtKey', 'RtKey2',
#        'Route', 'RouteName', 'TripKey', 'Trip', 'StopKey', 'Stop', 'StopName',
#        'Vehicle', 'VehicleType', 'SeatedCap', 'TotalCap', 'Lat', 'Lon',
#        'Boards', 'Alights', 'Onboard', 'Bike', 'Daytype', 'Hour', 'Minute',
#        'Second', 'Date', 'Powertrain', 'VehicleModel', 'Vehicle_mass',
#        'time_delta_in_seconds', 'dist', 'Speed', 'Acceleration', 'elevation',
#        'grade', 'VehicleWeight(lb)', 'Energy', 'stop_index', 'run'],
#       dtype='object')

# %%
# Load your GTFS static files
df_gtfs = pd.read_csv(r'../../data/tidy/google_transit/trips.txt')
df_gtfs['trip_id'] = df_gtfs['trip_id'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 3
#       1 # Load your GTFS static files
#       2 df_gtfs = pd.read_csv(r'../../data/tidy/google_transit/trips.txt')
# ----> 3 df_gtfs['trip_id'] = df_gtfs['trip_id'].astype(int)
#
# File ~\anaconda3\envs\ox\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
df_CDB_merged = pd.merge(df_CDB, df_gtfs, left_on='TripKey', right_on='trip_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 df_CDB_merged = pd.merge(df_CDB, df_gtfs, left_on='TripKey', right_on='trip_id', how='left')
#
# File ~\anaconda3\envs\ox\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
# ...

# %%
df_gtfs
# Out:
#       route_id                      service_id  \
# 0          R41          N2305-VATCo-Weekday-99
# 1          R41  N2305-VATCo-Weekday-99-1000000
# 2          R41          N2305-VATCo-Weekday-99
# 3          R41  N2305-VATCo-Weekday-99-1000000
# 4          R41          N2305-VATCo-Weekday-99
# ...        ...                             ...
# 11371       33           UM2223-UMTS-Sunday-23
# 11372      B79           UM2223-UMTS-Sunday-23
# 11373      B79           UM2223-UMTS-Sunday-23
# 11374      B79           UM2223-UMTS-Sunday-23
# 11375      B79           UM2223-UMTS-Sunday-23
#
#                                       trip_id  \
# 0              4017904-N2305-VATCo-Weekday-99
# 1      4017905-N2305-VATCo-Weekday-99-1000000
# 2              4017906-N2305-VATCo-Weekday-99
# 3      4017907-N2305-VATCo-Weekday-99-1000000
# 4              4017908-N2305-VATCo-Weekday-99
# ...                                       ...
# 11371           3835768-UM2223-UMTS-Sunday-23
# ...

# %%
df_CDB.loc[df_CDB['TripKey']==3835779]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, ServiceDateTime, DateKey, CalendarDate, Year, Month, OpKey, Operator, RtKey, RtKey2, Route, RouteName, TripKey, Trip, StopKey, Stop, StopName, Vehicle, VehicleType, SeatedCap, TotalCap, Lat, Lon, Boards, Alights, Onboard, Bike, Daytype, Hour, Minute, Second, Date, Powertrain, VehicleModel, Vehicle_mass, time_delta_in_seconds, dist, Speed, Acceleration, elevation, grade, VehicleWeight(lb), Energy, stop_index, run]
# Index: []
#
# [0 rows x 46 columns]

# %%
df_CDB[['TripKey','Trip']]
# Out:
#           TripKey        Trip
# 0          510824  (X) 0757-N
# 1          510824  (X) 0757-N
# 2          510824  (X) 0757-N
# 3          510824  (X) 0757-N
# 4          510824  (X) 0757-N
# ...           ...         ...
# 15583903   660365      1700-S
# 15583904   660365      1700-S
# 15583905   660365      1700-S
# 15583906   660365      1700-S
# 15583907   660365      1700-S
#
# [15583908 rows x 2 columns]

# %%
df_CDB.loc[df_CDB['TripKey']=='3835768']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, ServiceDateTime, DateKey, CalendarDate, Year, Month, OpKey, Operator, RtKey, RtKey2, Route, RouteName, TripKey, Trip, StopKey, Stop, StopName, Vehicle, VehicleType, SeatedCap, TotalCap, Lat, Lon, Boards, Alights, Onboard, Bike, Daytype, Hour, Minute, Second, Date, Powertrain, VehicleModel, Vehicle_mass, time_delta_in_seconds, dist, Speed, Acceleration, elevation, grade, VehicleWeight(lb), Energy, stop_index, run]
# Index: []
#
# [0 rows x 46 columns]

# %%
df_CDB['TripKey'].unique()
# Out:
# array([510824, 510829, 510846, ..., 660590, 660868, 663681], dtype=int64)

# %%
df_BEB['Route'].unique()
# Out:
# array(['30', '31', '33', '34', '35', '38', '39E', '45', '46', '801',
#        '802', '803', '804', '806', '820', '821', '823', '824', '892',
#        '902', '921', '943', '9999', 'B12', 'B17', 'B23', 'B4', 'B43',
#        'B48', 'B6', 'B7', 'B9', 'G1', 'G2', 'G3', 'G5', 'G73', 'P11',
#        'P20', 'P21', 'R10', 'R14', 'R24', 'R29', 'R41', 'R42', 'R44',
#        'X90', 'X92', '805', '36', 'B79', '890'], dtype=object)
