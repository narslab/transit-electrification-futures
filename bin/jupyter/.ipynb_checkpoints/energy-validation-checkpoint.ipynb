# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from matplotlib.pyplot import figure

# %%
### UMTS

# %%
xls = pd.ExcelFile(r'../../data/raw/fuel-export-20130701-20220712.xlsx')

# %%
df1 = pd.read_excel(xls, 'in')

# %%
df1.head()
# Out:
#             timestamp  bus_number  gallons  mileage  previous_mileage
# 0 2013-07-01 03:38:00        3214     39.3   222553          222371.0
# 1 2013-07-01 03:05:00        3301     33.2    42486           42289.0
# 2 2013-07-01 22:16:00        3214     21.5   222670          222553.0
# 3 2013-07-01 22:20:00        3224      5.2   151729          151686.0
# 4 2013-07-02 00:25:00        3226     11.2   152869          152807.0

# %%
df1.tail()
# Out:
#                 timestamp  bus_number  gallons  mileage  previous_mileage
# 60396 2022-07-12 01:42:00        3322     20.9    41209           41103.0
# 60397 2022-07-12 01:49:00        3225     38.7   423501          423351.0
# 60398 2022-07-12 01:51:00        3317     27.2    53363           53196.0
# 60399 2022-07-12 01:54:00        3301     43.6   324801          324552.0
# 60400 2022-07-12 01:58:00        3323     46.2    25241           25036.0

# %%
df1['timestamp']= pd.to_datetime(df1['timestamp'])

# %%
df1['bus_number'].unique()
# Out:
# array([3214, 3301, 3224, 3226, 3228, 3303, 3306, 3304, 3227, 3205, 3305,
#        3309, 3203, 3212, 3225, 3221, 3202, 3213, 3201, 3307, 3310, 3222,
#        3308, 3123, 3223, 3121, 3211, 3204, 3115, 3119, 3112, 3118, 3122,
#        3215, 3401, 3402, 3302, 3311, 3312, 3315, 3314, 3313, 3318, 3316,
#        3317, 3319, 3320, 3321, 3322, 3323, 3501, 3324, 3325, 3326],
#       dtype=int64)

# %%
df1.sort_values(by=['timestamp'], ascending=True, inplace=True)

# %%
df1['date'] = pd.to_datetime(df1['timestamp']).dt.date
df1['time'] = pd.to_datetime(df1['timestamp']).dt.time

# %%
#df1.head()

# %%
df1['date']=df1['date'].astype(str)

# %%
len(df1['date'].unique())
# Out:
# 3265

# %%
# df1

# %%
df1['time_delta'] = df1.groupby(['bus_number', 'date'])['timestamp'].diff()

# %%
df1['time_delta'].max()
# Out:
# Timedelta('0 days 23:59:00')

# %%
df1['time_delta'].min()
# Out:
# Timedelta('0 days 00:00:00')

# %%
df1.head()
# Out:
#             timestamp  bus_number  gallons  mileage  previous_mileage  \
# 1 2013-07-01 03:05:00        3301     33.2    42486           42289.0
# 0 2013-07-01 03:38:00        3214     39.3   222553          222371.0
# 2 2013-07-01 22:16:00        3214     21.5   222670          222553.0
# 3 2013-07-01 22:20:00        3224      5.2   151729          151686.0
# 6 2013-07-01 22:36:00        3303     21.5    48088           47881.0
#
#          date      time      time_delta  time_delta_in_seconds
# 1  2013-07-01  03:05:00             NaT                    NaN
# 0  2013-07-01  03:38:00             NaT                 1980.0
# 2  2013-07-01  22:16:00 0 days 18:38:00                67080.0
# 3  2013-07-01  22:20:00             NaT                  240.0
# 6  2013-07-01  22:36:00             NaT                  960.0

# %%
df1.time_delta=df1.time_delta.astype(str).str.replace('0 days ', '')

# %%
df1.head()
# Out:
#             timestamp  bus_number  gallons  mileage  previous_mileage  \
# 1 2013-07-01 03:05:00        3301     33.2    42486           42289.0
# 0 2013-07-01 03:38:00        3214     39.3   222553          222371.0
# 2 2013-07-01 22:16:00        3214     21.5   222670          222553.0
# 3 2013-07-01 22:20:00        3224      5.2   151729          151686.0
# 6 2013-07-01 22:36:00        3303     21.5    48088           47881.0
#
#          date      time time_delta  time_delta_in_seconds
# 1  2013-07-01  03:05:00        NaT                    NaN
# 0  2013-07-01  03:38:00        NaT                 1980.0
# 2  2013-07-01  22:16:00   18:38:00                67080.0
# 3  2013-07-01  22:20:00        NaT                  240.0
# 6  2013-07-01  22:36:00        NaT                  960.0

# %%
df1['time_delta']= pd.to_datetime(df1['time_delta'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60401 entries, 1 to 60400
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              60401 non-null  datetime64[ns]
#  1   bus_number             60401 non-null  int64
#  2   gallons                60400 non-null  float64
#  3   mileage                60401 non-null  int64
#  4   previous_mileage       60361 non-null  float64
#  5   date                   60401 non-null  object
#  6   time                   60401 non-null  object
#  7   time_delta             11546 non-null  datetime64[ns]
#  8   time_delta_in_seconds  57136 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(2)
# memory usage: 4.6+ MB

# %%
df1['time_delta_in_seconds'] = df1['time_delta'].dt.hour * 3600 + df1['time_delta'].dt.minute * 60 + df1['time_delta'].dt.second

# %%
df1.head()
# Out:
#             timestamp  bus_number  gallons  mileage  previous_mileage  \
# 1 2013-07-01 03:05:00        3301     33.2    42486           42289.0
# 0 2013-07-01 03:38:00        3214     39.3   222553          222371.0
# 2 2013-07-01 22:16:00        3214     21.5   222670          222553.0
# 3 2013-07-01 22:20:00        3224      5.2   151729          151686.0
# 6 2013-07-01 22:36:00        3303     21.5    48088           47881.0
#
#          date      time          time_delta  time_delta_in_seconds
# 1  2013-07-01  03:05:00                 NaT                    NaN
# 0  2013-07-01  03:38:00                 NaT                    NaN
# 2  2013-07-01  22:16:00 2022-07-17 18:38:00                67080.0
# 3  2013-07-01  22:20:00                 NaT                    NaN
# 6  2013-07-01  22:36:00                 NaT                    NaN

# %%
figure(figsize=(14, 9.5), dpi=300)
plt.plot_date(x=df1['timestamp']  , y=df1["time_delta_in_seconds"], fmt='o', tz=None, xdate=True, ydate=False, color='teal')
plt.ylabel("Time interval (s)", fontsize=36)
plt.xticks(fontsize=28, rotation = 45)
plt.yticks(fontsize=28)
plt.savefig(r'../../figures/time-intervals-fuel-filling-UMTS.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
plt.hist(df1['time_delta_in_seconds'], bins=100)
plt.show()

# %%
df1['time_delta_in_seconds'].max()
# Out:
# 86340.0

# %%
df1['time_delta_in_seconds'].min()
# Out:
# 0.0

# %%
df_time_intervals = df1[df1['time_delta_in_seconds'] > 0]
plt.hist(df_time_intervals['time_delta_in_seconds'])
plt.savefig(r'../../figures/hist-time-intervals-fuel-filling-UMTS.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
### CTF (Cottage Street)

# %%
#xls = pd.ExcelFile(r'../../data/tidy/CTF Fuel Tickets FY22.xlsx')

# %%
#df1 = pd.read_excel(xls, 'CTF')

# %%
#df1.head()

# %%
#df1['vehicle_year'] = df1['model'].str[:4]
#df1['model'] = df1['model'].str[5:]

# %%
#df1.head()

# %%
#df1.to_csv(r'../../data/tidy/CTF Fuel Tickets FY22-tidy.csv')

# %%
df1 = pd.read_csv(r'../../data/tidy/CTF Fuel Tickets FY22-tidy.csv', delimiter=',', skiprows=0, low_memory=False)

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'model', 'vehicle_year', 'type', 'Equipment ID', 'Qty',
#        'Transaction Date', 'Meter1Reading', 'Fuel Orfluid Type'],
#       dtype='object')

# %%
df1['model'].unique()
# Out:
# array(['GILLIG 30`', 'GILLIG 35`', 'GILLIG 40`', 'NEW FLYER XD35',
#        'NEW FLYER XD40', 'NEW FLYER XD40 (HYBRID)',
#        'PROTERRA CATALYST BE-40 (ELECTRIC)', 'NEW FLYER XE35 (ELECTRIC)',
#        'NEW FLYER XE40 (ELECTRIC)', 'UMTS GILLIG', 'UMTS NEW FLYER'],
#       dtype=object)

# %%
df1['model'].replace('GILLIG 30`', 'GILLIG', inplace=True)
df1['model'].replace('GILLIG 35`', 'GILLIG', inplace=True)
df1['model'].replace('GILLIG 40`', 'GILLIG', inplace=True)
df1['model'].replace('NEW FLYER XD35', 'NEW FLYER', inplace=True)
df1['model'].replace('NEW FLYER XD40', 'NEW FLYER', inplace=True)
df1['model'].replace('NEW FLYER XD40 (HYBRID)', 'NEW FLYER (HYBRID)', inplace=True)
df1['model'].replace('PROTERRA CATALYST BE-40 (ELECTRIC)', 'PROTERRA (ELECTRIC)', inplace=True)
df1['model'].replace('NEW FLYER XE35 (ELECTRIC)', 'NEW FLYER (ELECTRIC)', inplace=True)
df1['model'].replace('NEW FLYER XE40 (ELECTRIC)', 'NEW FLYER (ELECTRIC)', inplace=True)
df1['model'].replace('UMTS GILLIG', 'GILLIG', inplace=True)
df1['model'].replace('UMTS NEW FLYER', 'NEW FLYER', inplace=True)

# %%
df1['model'].unique()
# Out:
# array(['GILLIG', 'NEW FLYER', 'NEW FLYER (HYBRID)', 'PROTERRA (ELECTRIC)',
#        'NEW FLYER (ELECTRIC)'], dtype=object)

# %%
fig, ax = plt.subplots()
df1['model'].hist(figsize = (14,12), color='teal')
plt.ylabel("Bus models", fontsize=18)
plt.xlabel("Count", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# %%
### NTF (VATCo)

# %%
#xls2 = pd.ExcelFile(r'../../data/tidy/NTF Fuel Tickets FY22.xlsx')

# %%
#df2 = pd.read_excel(xls, 'NTF')

# %%
#df2.head()

# %%
#df2['Model'].unique()

# %%
#df2['vehicle_year'] = df2['Model'].str[:4]
#df2.rename(columns = {'Model':'model'}, inplace = True)

# %%
#df2.to_csv(r'../../data/tidy/NTF Fuel Tickets FY22-tidy.csv')

# %%
df2 = pd.read_csv(r'../../data/tidy/NTF Fuel Tickets FY22-tidy.csv', delimiter=',', skiprows=0, low_memory=False)

# %%
df2.head()
# Out:
#    Unnamed: 0            model  vehicle_year          type  Equipment ID  \
# 0           0  2007 GILLIG 40`          2007  conventional          7610
# 1           1  2007 GILLIG 40`          2007  conventional          7610
# 2           2  2007 GILLIG 40`          2007  conventional          7610
# 3           3  2007 GILLIG 40`          2007  conventional          7610
# 4           4  2007 GILLIG 40`          2007  conventional          7610
#
#     Qty Transaction Date  Meter1Reading Fuel Orfluid Type
# 0  25.8   7/1/2021 20:05         492882               DIE
# 1  18.8   7/2/2021 19:09         492984               DIE
# 2  20.8   7/3/2021 14:03         493087               DIE
# 3  24.6   7/6/2021 15:46         493224               DIE
# 4  24.0   7/7/2021 19:00         493327               DIE

# %%
df2['model'].replace('2007 GILLIG 40`', 'GILLIG', inplace=True)
df2['model'].replace('2008 GILLIG 35`', 'GILLIG', inplace=True)
df2['model'].replace('2009 GILLIG 40`', 'GILLIG', inplace=True)
df2['model'].replace('2010 GILLIG 35`', 'GILLIG', inplace=True)
df2['model'].replace('2011 NEW FLYER XD40', 'NEW FLYER', inplace=True)
df2['model'].replace('2012 NEW FLYER XD40', 'NEW FLYER', inplace=True)
df2['model'].replace('2013 NEW FLYER XDE60 (ARTIC) (HYBRID)', 'NEW FLYER (HYBRID)', inplace=True)
df2['model'].replace('2020 NEW FLYER XD35', 'NEW FLYER', inplace=True)
df2['model'].replace('2021 NEW FLYER XD40', 'NEW FLYER', inplace=True)
df2['model'].replace('2021 NEW FLYER XE40 (ELECTRIC)', 'NEW FLYER (ELECTRIC)', inplace=True)
df2['model'].replace('2022 NEW FLYER XD40', 'NEW FLYER', inplace=True)

# %%
df2['model'].unique()
# Out:
# array(['GILLIG', 'NEW FLYER', 'NEW FLYER (HYBRID)',
#        'NEW FLYER (ELECTRIC)'], dtype=object)

# %%
fig, ax = plt.subplots()
df2['model'].hist(figsize = (14,12), color='teal')
plt.ylabel("Bus models", fontsize=18)
plt.xlabel("Count", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
frames = [df1, df2]
result = pd.concat(frames)

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'model', 'vehicle_year', 'type', 'Equipment ID', 'Qty',
#        'Transaction Date', 'Meter1Reading', 'Fuel Orfluid Type'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
data=result.groupby(by=['Equipment ID'])['model']
#result['model'].groupby('Equipment ID').hist(figsize = (14,12), color='teal')
data.hist(figsize = (14,12), color='teal')
plt.ylabel("Bus models", fontsize=18)
plt.xlabel("Count", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
fig.savefig(r'../../figures/hist-fleet-models.png', dpi=400, bbox_inches='tight')
