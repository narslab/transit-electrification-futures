# %%
import pandas as pd

# %%
df_final = pd.read_csv(r'../../results/fuel-rates-CDB-CHB.csv', delimiter=',', skiprows=0, low_memory=False)

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0.4', 'Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0',
#        'ServiceDateTime', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'DateKey',
#        'CalendarDate', 'Year', 'Month', 'OpKey', 'Operator', 'RtKey', 'RtKey2',
#        'Route', 'RouteName', 'TripKey', 'Trip', 'StopKey', 'Stop', 'StopName',
#        'Lat', 'Lon', 'Vehicle', 'VehicleType', 'SeatedCap', 'TotalCap',
#        'Boards', 'Alights', 'Onboard', 'Bike', 'Wheelchair', 'Weekday', 'Hour',
#        'Minute', 'Second', 'Date', 'Daytype', 'time', 'geometry', 'dist',
#        'Speed', 'Acceleration', 'time_delta', 'time_delta_in_seconds',
#        'Powertrain', 'VehicleModel', 'Vehicle_mass', 'FuelRate(L/s)'],
#       dtype='object')

# %%
df_final.Vehicle_mass
# Out:
# 0          26440.0
# 1          26440.0
# 2          26440.0
# 3          26440.0
# 4          26440.0
#             ...
# 1099395        0.0
# 1099396        0.0
# 1099397        0.0
# 1099398        0.0
# 1099399        0.0
# Name: Vehicle_mass, Length: 1099400, dtype: float64

# %%
zeros = df_final[df_final['FuelRate(L/s)'] == 0]
zeros
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.3, Unnamed: 0.2, Unnamed: 0, ServiceDateTime, Unnamed: 0.1, Unnamed: 0.1.1, DateKey, CalendarDate, Year, Month, OpKey, Operator, RtKey, RtKey2, Route, RouteName, TripKey, Trip, StopKey, Stop, StopName, Lat, Lon, Vehicle, VehicleType, SeatedCap, TotalCap, Boards, Alights, Onboard, Bike, Wheelchair, Weekday, Hour, Minute, Second, Date, Daytype, time, geometry, dist, Speed, Acceleration, time_delta, time_delta_in_seconds, Powertrain, VehicleModel, Vehicle_mass, FuelRate(L/s)]
# Index: []
#
# [0 rows x 49 columns]

# %%
for i in df_final.index:
    if i==0:
        df_final.at[i , 'FuelRate(L/s)'] = 0
    elif df_final['Vehicle_mass']==0:
        df_final.at[i , 'FuelRate(L/s)'] = 0
    else:
        if df_final['Vehicle'].loc[i]==df_final['Vehicle'].loc[i-1]:
            if df_final['Date'].loc[i]!=df_final['Date'].loc[i-1]:
                df_final.at[i , 'FuelRate(L/s)'] = 0
        else:
            df_final.at[i , 'FuelRate(L/s)'] = 0

# %%
df_final
# Out:
#          Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0      ServiceDateTime  \
# 0                1415          1415       33217  2022-04-01 05:55:38
# 1                1591          1591       33219  2022-04-01 06:04:01
# 2                1592          1592       33218  2022-04-01 06:04:01
# 3                1646          1646       33220  2022-04-01 06:05:51
# 4                1656          1656       33221  2022-04-01 06:06:13
# ...               ...           ...         ...                  ...
# 1099395       1361526       1361526     1361544  2022-04-30 23:54:20
# 1099396       1361530       1361530     1361545  2022-04-30 23:55:24
# 1099397       1361539       1361539     1361546  2022-04-30 23:56:47
# 1099398       1361541       1361541     1361547  2022-04-30 23:57:32
# 1099399       1361546       1361546     1361548  2022-04-30 23:59:29
#
#          Unnamed: 0.1  Unnamed: 0.1.1  DateKey             CalendarDate  Year  \
# ...

# %%
zeros = df_final[df_final['FuelRate(L/s)'] == 0]
zeros
# Out:
#          Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0      ServiceDateTime  \
# 0                1415          1415       33217  2022-04-01 05:55:38
# 317             56565         56565       33534  2022-04-02 07:30:24
# 494            137578        137578       33711  2022-04-04 14:03:19
# 550            163594        163594       33767  2022-04-05 05:35:57
# 988            217526        217526       34205  2022-04-06 06:00:39
# ...               ...           ...         ...                  ...
# 1097940       1136687       1136687     1360089  2022-04-26 14:20:25
# 1098095       1167154       1167154     1360244  2022-04-27 07:49:01
# 1098338       1214975       1214975     1360487  2022-04-28 00:01:26
# 1098574       1268760       1268760     1360723  2022-04-29 00:01:21
# 1098870       1323709       1323709     1361019  2022-04-30 00:02:08
#
#          Unnamed: 0.1  Unnamed: 0.1.1  DateKey             CalendarDate  Year  \
# ...

# %%
df_final.to_csv(r'../../results/fuel-rates-CDB-CHB.csv')
