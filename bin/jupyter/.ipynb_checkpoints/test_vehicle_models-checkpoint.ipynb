# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from matplotlib.pyplot import figure
import matplotlib.dates as mdates
import datetime
import seaborn as sns

# %%
df_validation = pd.read_csv(r'../../data/tidy/energy_validation_april2022.csv', delimiter=',', skiprows=0, low_memory=False)

# %%
df_model = pd.read_csv(r'../../results/computed-fuel-rates.csv', delimiter=',', skiprows=0, low_memory=False)

# %%
df_validation
# Out:
#       Unnamed: 0            timestamp  equipment_id  gallons        date
# 0          58932  2022-04-01 00:04:00          3213     46.9  2022-04-01
# 1          58933  2022-04-01 00:11:00          3303     16.0  2022-04-01
# 2          58934  2022-04-01 00:19:00          3322     31.7  2022-04-01
# 3          58935  2022-04-01 00:28:00          3312     35.2  2022-04-01
# 4          58936  2022-04-01 00:33:00          3307     33.4  2022-04-01
# ...          ...                  ...           ...      ...         ...
# 2997        4682      4/26/2022 19:12          7816     51.6  2022-04-26
# 2998        4683      4/27/2022 20:39          7816     19.3  2022-04-27
# 2999        4684      4/28/2022 14:02          7816     14.0  2022-04-28
# 3000        4685      4/29/2022 19:10          7816     18.4  2022-04-29
# 3001        4686      4/30/2022 13:02          7816     19.9  2022-04-30
#
# [3002 rows x 5 columns]

# %%
df_model
# Out:
#          Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0  \
# 0                   0       1297419       1297419        2391
# 1                   1       1299038       1299038        2392
# 2                   2       1299039       1299039        2393
# 3                   3       1299250       1299250        2394
# 4                   4       1299272       1299272        2395
# ...               ...           ...           ...         ...
# 1127243       1127243       1361526       1361526     1361544
# 1127244       1127244       1361530       1361530     1361545
# 1127245       1127245       1361539       1361539     1361546
# 1127246       1127246       1361541       1361541     1361547
# 1127247       1127247       1361546       1361546     1361548
#
#              ServiceDateTime  Unnamed: 0.1  Unnamed: 0.1.1  DateKey  \
# 0        2022-04-29 14:01:44          2391         1273034     8788
# 1        2022-04-29 14:28:20          2392         1273037     8788
# 2        2022-04-29 14:28:20          2393         1273500     8788
# 3        2022-04-29 14:30:55          2394         1273501     8788
# 4        2022-04-29 14:31:09          2395         1273502     8788
# ...                      ...           ...             ...      ...
# 1127243  2022-04-30 23:54:20       1361544         1325566     8789
# 1127244  2022-04-30 23:55:24       1361545         1325567     8789
# 1127245  2022-04-30 23:56:47       1361546         1325568     8789
# 1127246  2022-04-30 23:57:32       1361547         1325569     8789
# 1127247  2022-04-30 23:59:29       1361548         1325570     8789
#
#                     CalendarDate  Year  ...                    geometry  \
# 0        2022-04-29 00:00:00.000  2022  ...  POINT (-72.52602 42.14098)
# 1        2022-04-29 00:00:00.000  2022  ...  POINT (-72.65278 42.19514)
# 2        2022-04-29 00:00:00.000  2022  ...  POINT (-72.65278 42.19514)
# 3        2022-04-29 00:00:00.000  2022  ...  POINT (-72.64553 42.20302)
# 4        2022-04-29 00:00:00.000  2022  ...  POINT (-72.64369 42.20166)
# ...                          ...   ...  ...                         ...
# 1127243  2022-04-30 00:00:00.000  2022  ...  POINT (-72.53185 42.38201)
# 1127244  2022-04-30 00:00:00.000  2022  ...     POINT (-72.5327 42.375)
# 1127245  2022-04-30 00:00:00.000  2022  ...  POINT (-72.53357 42.36864)
# 1127246  2022-04-30 00:00:00.000  2022  ...   POINT (-72.53556 42.3656)
# 1127247  2022-04-30 00:00:00.000  2022  ...  POINT (-72.54673 42.35999)
#
#              dist      Speed  Acceleration       time_delta  \
# 0        0.000000   0.000000      0.000000                0
# 1        8.829565  32.052117      0.005579  0 days 00:26:36
# 2        0.000000   0.000000      0.000000  0 days 00:00:00
# 3        0.526585  19.682810      0.035274  0 days 00:02:35
# 4        0.130185  53.874613      0.678410  0 days 00:00:14
# ...           ...        ...           ...              ...
# 1127243  0.254140  10.517075      0.003673  0 days 00:02:20
# 1127244  0.156799  14.194300      0.015960  0 days 00:01:04
# 1127245  0.144950  10.117888     -0.013643  0 days 00:01:23
# 1127246  0.151259  19.474153      0.057755  0 days 00:00:45
# 1127247  0.780486  38.648220      0.045523  0 days 00:01:57
#
#         time_delta_in_seconds    Powertrain           VehicleModel  \
# 0                         0.0      electric  New Flyer 35 electric
# 1                      1596.0      electric  New Flyer 35 electric
# 2                         0.0      electric  New Flyer 35 electric
# 3                       155.0      electric  New Flyer 35 electric
# 4                        14.0      electric  New Flyer 35 electric
# ...                       ...           ...                    ...
# 1127243                 140.0  conventional                      0
# 1127244                  64.0  conventional                      0
# 1127245                  83.0  conventional                      0
# 1127246                  45.0  conventional                      0
# 1127247                 117.0  conventional                      0
#
#         Vehicle_mass  FuelRate/Energy
# 0            26900.0         0.000000
# 1            26900.0        10.919433
# 2            26900.0         0.000000
# 3            26900.0         0.807272
# 4            26900.0         1.329511
# ...              ...              ...
# 1127243          0.0         0.000000
# 1127244          0.0         0.000000
# 1127245          0.0         0.000000
# 1127246          0.0         0.000000
# 1127247          0.0         0.000000
#
# [1127248 rows x 50 columns]

# %%
df_model[df_model['Vehicle_mass']==0]
# Out:
#          Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0  \
# 304823         304823        196799        196799      310192
# 304824         304824        196865        196865      310193
# 304825         304825        197019        197019      310194
# 304826         304826        197217        197217      310195
# 304827         304827        197263        197263      310196
# ...               ...           ...           ...         ...
# 1127243       1127243       1361526       1361526     1361544
# 1127244       1127244       1361530       1361530     1361545
# 1127245       1127245       1361539       1361539     1361546
# 1127246       1127246       1361541       1361541     1361547
# 1127247       1127247       1361546       1361546     1361548
#
#              ServiceDateTime  Unnamed: 0.1  Unnamed: 0.1.1  DateKey  \
# 304823   2022-04-05 15:25:46        310192          188911     8764
# 304824   2022-04-05 15:27:03        310193          188912     8764
# 304825   2022-04-05 15:29:36        310194          188913     8764
# 304826   2022-04-05 15:32:38        310195          188914     8764
# 304827   2022-04-05 15:33:08        310196          188915     8764
# ...                      ...           ...             ...      ...
# 1127243  2022-04-30 23:54:20       1361544         1325566     8789
# 1127244  2022-04-30 23:55:24       1361545         1325567     8789
# 1127245  2022-04-30 23:56:47       1361546         1325568     8789
# 1127246  2022-04-30 23:57:32       1361547         1325569     8789
# 1127247  2022-04-30 23:59:29       1361548         1325570     8789
#
#                     CalendarDate  Year  ...                    geometry  \
# 304823   2022-04-05 00:00:00.000  2022  ...  POINT (-72.58206 42.13765)
# 304824   2022-04-05 00:00:00.000  2022  ...  POINT (-72.57904 42.13794)
# 304825   2022-04-05 00:00:00.000  2022  ...  POINT (-72.57469 42.14085)
# 304826   2022-04-05 00:00:00.000  2022  ...   POINT (-72.5829 42.13877)
# 304827   2022-04-05 00:00:00.000  2022  ...  POINT (-72.58431 42.13566)
# ...                          ...   ...  ...                         ...
# 1127243  2022-04-30 00:00:00.000  2022  ...  POINT (-72.53185 42.38201)
# 1127244  2022-04-30 00:00:00.000  2022  ...     POINT (-72.5327 42.375)
# 1127245  2022-04-30 00:00:00.000  2022  ...  POINT (-72.53357 42.36864)
# 1127246  2022-04-30 00:00:00.000  2022  ...   POINT (-72.53556 42.3656)
# 1127247  2022-04-30 00:00:00.000  2022  ...  POINT (-72.54673 42.35999)
#
#              dist      Speed  Acceleration       time_delta  \
# 304823   0.000000   0.000000      0.000000                0
# 304824   0.208748  15.706615      0.056662  0 days 00:01:17
# 304825   0.306527  11.607189     -0.007443  0 days 00:02:33
# 304826   0.568886  18.109419      0.009924  0 days 00:03:02
# 304827   0.116737  22.544429      0.041065  0 days 00:00:30
# ...           ...        ...           ...              ...
# 1127243  0.254140  10.517075      0.003673  0 days 00:02:20
# 1127244  0.156799  14.194300      0.015960  0 days 00:01:04
# 1127245  0.144950  10.117888     -0.013643  0 days 00:01:23
# 1127246  0.151259  19.474153      0.057755  0 days 00:00:45
# 1127247  0.780486  38.648220      0.045523  0 days 00:01:57
#
#         time_delta_in_seconds    Powertrain            VehicleModel  \
# 304823                    0.0  conventional  New Flyer conventional
# 304824                   77.0  conventional  New Flyer conventional
# 304825                  153.0  conventional  New Flyer conventional
# 304826                  182.0  conventional  New Flyer conventional
# 304827                   30.0  conventional  New Flyer conventional
# ...                       ...           ...                     ...
# 1127243                 140.0  conventional                       0
# 1127244                  64.0  conventional                       0
# 1127245                  83.0  conventional                       0
# 1127246                  45.0  conventional                       0
# 1127247                 117.0  conventional                       0
#
#         Vehicle_mass  FuelRate/Energy
# 304823           0.0              0.0
# 304824           0.0              0.0
# 304825           0.0              0.0
# 304826           0.0              0.0
# 304827           0.0              0.0
# ...              ...              ...
# 1127243          0.0              0.0
# 1127244          0.0              0.0
# 1127245          0.0              0.0
# 1127246          0.0              0.0
# 1127247          0.0              0.0
#
# [408881 rows x 50 columns]

# %%
unknown_vehicles=df_model.loc[df_model['Vehicle_mass'] == 0, 'Vehicle']
unknown_vehicle_list=unknown_vehicles.unique()
unknown_vehicle_list
# Out:
# array([1701, 1710, 1711, 1712, 1714, 1715, 1716, 1717, 1718, 1719, 1720,
#        1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1811, 1812,
#        1813, 1814, 1815, 1817, 1819, 1821, 1822, 1823, 1824, 1825, 1826,
#        3307, 3308, 7553, 7554, 7661, 7662, 7801, 7802, 7811, 7812, 7813,
#        7814, 7815, 7902], dtype=int64)

# %%
check=df_model.loc[df_model['Vehicle'].isin(unknown_vehicle_list)]

# %%
check.columns
# Out:
# Index(['Unnamed: 0.4', 'Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0',
#        'ServiceDateTime', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'DateKey',
#        'CalendarDate', 'Year', 'Month', 'OpKey', 'Operator', 'RtKey', 'RtKey2',
#        'Route', 'RouteName', 'TripKey', 'Trip', 'StopKey', 'Stop', 'StopName',
#        'Lat', 'Lon', 'Vehicle', 'VehicleType', 'SeatedCap', 'TotalCap',
#        'Boards', 'Alights', 'Onboard', 'Bike', 'Wheelchair', 'Weekday', 'Hour',
#        'Minute', 'Second', 'Date', 'Daytype', 'time', 'geometry', 'dist',
#        'Speed', 'Acceleration', 'time_delta', 'time_delta_in_seconds',
#        'Powertrain', 'VehicleModel', 'Vehicle_mass', 'FuelRate/Energy'],
#       dtype='object')

# %%
check.VehicleType.unique()
# Out:
# array(['2011 New Flyer', '2015 New Flyer 35ft', 'New Flyer 2020', '0',
#        '2020 New Flyer', '2021', '2021 bus', '2022 New Flyer',
#        '2011 NewFlyer', '2012 New Flyer', '2011 New Flyer 35ft', '7661',
#        '7662', '2011 New Flyer - 7801', '2011 New Flyer - 7802',
#        '2011 New Flyer - 7811', '2011 New Flyer - 7812',
#        '2011 New Flyer - 7813', '2011 New Flyer - 7814',
#        '2011 New Flyer - 7815', 'Articulated Buses - V9000'], dtype=object)

# %%
df_model_diesel = df_model[df_model.Powertrain != 'electric'].copy()

# %%
df_model_diesel_filtered=df_model_diesel[df_model_diesel['FuelRate/Energy']<=1].copy()

# %%
df_model_diesel_filtered
# Out:
#          Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0  \
# 27848           27848          1415          1415       33217
# 27849           27849          1591          1591       33219
# 27850           27850          1592          1592       33218
# 27851           27851          1646          1646       33220
# 27852           27852          1656          1656       33221
# ...               ...           ...           ...         ...
# 1127243       1127243       1361526       1361526     1361544
# 1127244       1127244       1361530       1361530     1361545
# 1127245       1127245       1361539       1361539     1361546
# 1127246       1127246       1361541       1361541     1361547
# 1127247       1127247       1361546       1361546     1361548
#
#              ServiceDateTime  Unnamed: 0.1  Unnamed: 0.1.1  DateKey  \
# 27848    2022-04-01 05:55:38         33217           43687     8760
# 27849    2022-04-01 06:04:01         33219           43689     8760
# 27850    2022-04-01 06:04:01         33218           41707     8760
# 27851    2022-04-01 06:05:51         33220           41708     8760
# 27852    2022-04-01 06:06:13         33221           41709     8760
# ...                      ...           ...             ...      ...
# 1127243  2022-04-30 23:54:20       1361544         1325566     8789
# 1127244  2022-04-30 23:55:24       1361545         1325567     8789
# 1127245  2022-04-30 23:56:47       1361546         1325568     8789
# 1127246  2022-04-30 23:57:32       1361547         1325569     8789
# 1127247  2022-04-30 23:59:29       1361548         1325570     8789
#
#                     CalendarDate  Year  ...                    geometry  \
# 27848    2022-04-01 00:00:00.000  2022  ...  POINT (-72.52602 42.14099)
# 27849    2022-04-01 00:00:00.000  2022  ...  POINT (-72.54524 42.13793)
# 27850    2022-04-01 00:00:00.000  2022  ...  POINT (-72.54524 42.13793)
# 27851    2022-04-01 00:00:00.000  2022  ...  POINT (-72.54618 42.13219)
# 27852    2022-04-01 00:00:00.000  2022  ...  POINT (-72.54585 42.12965)
# ...                          ...   ...  ...                         ...
# 1127243  2022-04-30 00:00:00.000  2022  ...  POINT (-72.53185 42.38201)
# 1127244  2022-04-30 00:00:00.000  2022  ...     POINT (-72.5327 42.375)
# 1127245  2022-04-30 00:00:00.000  2022  ...  POINT (-72.53357 42.36864)
# 1127246  2022-04-30 00:00:00.000  2022  ...   POINT (-72.53556 42.3656)
# 1127247  2022-04-30 00:00:00.000  2022  ...  POINT (-72.54673 42.35999)
#
#              dist      Speed  Acceleration       time_delta  \
# 27848    0.000000   0.000000      0.000000                0
# 27849    0.000000   0.000000      0.000000  0 days 00:08:23
# 27850    1.329491  15.313257      0.008457  0 days 00:00:00
# 27851    0.135532   7.138389      0.018026  0 days 00:01:50
# 27852    0.057365  15.106779      0.100611  0 days 00:00:22
# ...           ...        ...           ...              ...
# 1127243  0.254140  10.517075      0.003673  0 days 00:02:20
# 1127244  0.156799  14.194300      0.015960  0 days 00:01:04
# 1127245  0.144950  10.117888     -0.013643  0 days 00:01:23
# 1127246  0.151259  19.474153      0.057755  0 days 00:00:45
# 1127247  0.780486  38.648220      0.045523  0 days 00:01:57
#
#         time_delta_in_seconds    Powertrain         VehicleModel Vehicle_mass  \
# 27848                     0.0  conventional  Gillig conventional      26440.0
# 27849                   503.0  conventional  Gillig conventional      26440.0
# 27850                     0.0  conventional  Gillig conventional      26440.0
# 27851                   110.0  conventional  Gillig conventional      26440.0
# 27852                    22.0  conventional  Gillig conventional      26440.0
# ...                       ...           ...                  ...          ...
# 1127243                 140.0  conventional                    0          0.0
# 1127244                  64.0  conventional                    0          0.0
# 1127245                  83.0  conventional                    0          0.0
# 1127246                  45.0  conventional                    0          0.0
# 1127247                 117.0  conventional                    0          0.0
#
#          FuelRate/Energy
# 27848           0.000000
# 27849           0.001660
# 27850           0.102148
# 27851           0.051260
# 27852           0.204526
# ...                  ...
# 1127243         0.000000
# 1127244         0.000000
# 1127245         0.000000
# 1127246         0.000000
# 1127247         0.000000
#
# [985052 rows x 50 columns]

# %%
df_model_diesel_filtered['Fuel_consumption']=df_model_diesel_filtered['FuelRate/Energy']*df_model_diesel_filtered['time_delta_in_seconds']

# %%
#df_model = df_model.fillna(0)
#df_model['FuelRate/Energy'] = pd.to_numeric(df_model['FuelRate/Energy'])
df_daily_fuel = df_model_diesel_filtered.groupby(['Date']).agg({'Fuel_consumption':'sum'})[['Fuel_consumption']].reset_index()
df_daily_fuel['Fuel_consumption']=(df_daily_fuel['Fuel_consumption'])/3.78541 # 1 gallon = 3.78541 liter
#df_daily_fuel['FuelRate/Energy']=(24*60*60*df_daily_fuel['FuelRate/Energy'])/3.78541 # 1 gallon = 3.78541 liter
df_daily_fuel
# Out:
#           Date  Fuel_consumption
# 0   2022-04-01      48327.685206
# 1   2022-04-02      30317.457384
# 2   2022-04-03      11758.605895
# 3   2022-04-04      45484.756987
# 4   2022-04-05      45790.261328
# 5   2022-04-06      47293.475187
# 6   2022-04-07      46567.277848
# 7   2022-04-08      45878.222067
# 8   2022-04-09      31675.069697
# 9   2022-04-10      11638.876578
# 10  2022-04-11      45470.326089
# 11  2022-04-12      45557.809084
# 12  2022-04-13      42384.240350
# 13  2022-04-14      44922.242100
# 14  2022-04-15      39289.639582
# 15  2022-04-16      28704.608071
# 16  2022-04-17       7469.625828
# 17  2022-04-18      35549.837626
# 18  2022-04-19      39009.853448
# 19  2022-04-20      36813.204066
# 20  2022-04-21      38698.667240
# 21  2022-04-22      39307.869877
# 22  2022-04-23      27044.970797
# 23  2022-04-24       9209.561709
# 24  2022-04-25      45729.880652
# 25  2022-04-26      43172.677577
# 26  2022-04-27      45067.871577
# 27  2022-04-28      42741.602103
# 28  2022-04-29      47310.610115
# 29  2022-04-30      28846.980530

# %%
df_daily_fuel.plot(x="Date", y="Fuel_consumption", color='teal', figsize=(12, 5))
plt.ylabel("Fuel consumption (gallons)", fontsize=16)
plt.xlabel("Day", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig(r'../../figures/fuel-consumption-model.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
df_daily_fuel = df_model_diesel_filtered.groupby(['Date']).agg({'FuelRate/Energy':'mean'})[['FuelRate/Energy']].reset_index()
df_daily_fuel['FuelRate/Energy']=(24*60*60*df_daily_fuel['FuelRate/Energy'])/3.78541 # 1 gallon = 3.78541 liter
df_daily_fuel
# Out:
#           Date  FuelRate/Energy
# 0   2022-04-01      2039.720733
# 1   2022-04-02      2053.785311
# 2   2022-04-03      1826.269061
# 3   2022-04-04      2104.662094
# 4   2022-04-05      2068.230324
# 5   2022-04-06      2066.905808
# 6   2022-04-07      2092.530620
# 7   2022-04-08      1841.672187
# 8   2022-04-09      1916.563950
# 9   2022-04-10      1893.327750
# 10  2022-04-11      2141.910973
# 11  2022-04-12      2099.269653
# 12  2022-04-13      1858.581186
# 13  2022-04-14      1955.743541
# 14  2022-04-15      1903.545146
# 15  2022-04-16      1663.912498
# 16  2022-04-17      1177.150839
# 17  2022-04-18      2051.171107
# 18  2022-04-19      2014.109916
# 19  2022-04-20      1861.587834
# 20  2022-04-21      1869.510022
# 21  2022-04-22      1893.765082
# 22  2022-04-23      1738.920108
# 23  2022-04-24      1650.613628
# 24  2022-04-25      2009.013259
# 25  2022-04-26      2060.192350
# 26  2022-04-27      1976.327889
# 27  2022-04-28      1865.565243
# 28  2022-04-29      2096.666135
# 29  2022-04-30      1883.116226

# %%
df_daily_fuel.plot(x="Date", y="FuelRate/Energy", color='teal', figsize=(12, 5))
plt.ylabel("Fuel consumption (gallons)", fontsize=16)
plt.xlabel("Day", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.savefig(r'../../figures/fuel-consumption-model-diesel.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
df_model_electric = df_model[df_model.Powertrain == 'electric'].copy()

# %%
df_model_electric
# Out:
#        Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0  \
# 0                 0       1297419       1297419        2391
# 1                 1       1299038       1299038        2392
# 2                 2       1299039       1299039        2393
# 3                 3       1299250       1299250        2394
# 4                 4       1299272       1299272        2395
# ...             ...           ...           ...         ...
# 27843         27843       1319911       1319911       33212
# 27844         27844       1319922       1319922       33213
# 27845         27845       1319927       1319927       33214
# 27846         27846       1320030       1320030       33216
# 27847         27847       1320031       1320031       33215
#
#            ServiceDateTime  Unnamed: 0.1  Unnamed: 0.1.1  DateKey  \
# 0      2022-04-29 14:01:44          2391         1273034     8788
# 1      2022-04-29 14:28:20          2392         1273037     8788
# 2      2022-04-29 14:28:20          2393         1273500     8788
# 3      2022-04-29 14:30:55          2394         1273501     8788
# 4      2022-04-29 14:31:09          2395         1273502     8788
# ...                    ...           ...             ...      ...
# 27843  2022-04-29 20:24:34         33212         1301441     8788
# 27844  2022-04-29 20:24:44         33213         1301442     8788
# 27845  2022-04-29 20:24:53         33214         1301443     8788
# 27846  2022-04-29 20:27:55         33216         1301444     8788
# 27847  2022-04-29 20:27:55         33215         1273215     8788
#
#                   CalendarDate  Year  ...                    geometry  \
# 0      2022-04-29 00:00:00.000  2022  ...  POINT (-72.52602 42.14098)
# 1      2022-04-29 00:00:00.000  2022  ...  POINT (-72.65278 42.19514)
# 2      2022-04-29 00:00:00.000  2022  ...  POINT (-72.65278 42.19514)
# 3      2022-04-29 00:00:00.000  2022  ...  POINT (-72.64553 42.20302)
# 4      2022-04-29 00:00:00.000  2022  ...  POINT (-72.64369 42.20166)
# ...                        ...   ...  ...                         ...
# 27843  2022-04-29 00:00:00.000  2022  ...  POINT (-72.60081 42.10913)
# 27844  2022-04-29 00:00:00.000  2022  ...  POINT (-72.59953 42.10789)
# 27845  2022-04-29 00:00:00.000  2022  ...   POINT (-72.5986 42.10695)
# 27846  2022-04-29 00:00:00.000  2022  ...  POINT (-72.59471 42.10589)
# 27847  2022-04-29 00:00:00.000  2022  ...  POINT (-72.59471 42.10589)
#
#            dist      Speed  Acceleration       time_delta  \
# 0      0.000000   0.000000      0.000000                0
# 1      8.829565  32.052117      0.005579  0 days 00:26:36
# 2      0.000000   0.000000      0.000000  0 days 00:00:00
# 3      0.526585  19.682810      0.035274  0 days 00:02:35
# 4      0.130185  53.874613      0.678410  0 days 00:00:14
# ...         ...        ...           ...              ...
# 27843  0.188877  21.456513     -0.295809  0 days 00:00:51
# 27844  0.092076  53.345279      0.885801  0 days 00:00:10
# 27845  0.067128  43.212870     -0.312729  0 days 00:00:09
# 27846  0.000000   0.000000      0.000000  0 days 00:03:02
# 27847  0.269665   8.584260     -0.052852  0 days 00:00:00
#
#       time_delta_in_seconds Powertrain           VehicleModel Vehicle_mass  \
# 0                       0.0   electric  New Flyer 35 electric      26900.0
# 1                    1596.0   electric  New Flyer 35 electric      26900.0
# 2                       0.0   electric  New Flyer 35 electric      26900.0
# 3                     155.0   electric  New Flyer 35 electric      26900.0
# 4                      14.0   electric  New Flyer 35 electric      26900.0
# ...                     ...        ...                    ...          ...
# 27843                  51.0   electric  New Flyer 40 electric      32770.0
# 27844                  10.0   electric  New Flyer 40 electric      32770.0
# 27845                   9.0   electric  New Flyer 40 electric      32770.0
# 27846                 182.0   electric  New Flyer 40 electric      32770.0
# 27847                   0.0   electric  New Flyer 40 electric      32770.0
#
#        FuelRate/Energy
# 0             0.000000
# 1            10.919433
# 2             0.000000
# 3             0.807272
# 4             1.329511
# ...                ...
# 27843        -0.576331
# 27844         1.495874
# 27845        -0.210776
# 27846         0.000000
# 27847         0.000000
#
# [27848 rows x 50 columns]

# %%
df_daily_energy = df_model_electric.groupby(['Date']).agg({'FuelRate/Energy':'mean'})[['FuelRate/Energy']].reset_index()
df_daily_energy['FuelRate/Energy']=(24*df_daily_energy['FuelRate/Energy'])/3.78541 # 1 gallon = 3.78541 liter
df_daily_energy
# Out:
#           Date  FuelRate/Energy
# 0   2022-04-01         2.905506
# 1   2022-04-04         2.241342
# 2   2022-04-05         3.146942
# 3   2022-04-06         3.877507
# 4   2022-04-07         2.404789
# 5   2022-04-08         3.698125
# 6   2022-04-11         2.341545
# 7   2022-04-12         2.603957
# 8   2022-04-13         2.493259
# 9   2022-04-14         1.997582
# 10  2022-04-15         2.702190
# 11  2022-04-18         2.351911
# 12  2022-04-19         2.257772
# 13  2022-04-20         2.647485
# 14  2022-04-21         2.418743
# 15  2022-04-22         3.822759
# 16  2022-04-25         2.709359
# 17  2022-04-26         2.960487
# 18  2022-04-27         2.849537
# 19  2022-04-28         3.663890
# 20  2022-04-29         2.445213

# %%
df_daily_energy.plot(x="Date", y="FuelRate/Energy", color='teal', figsize=(12, 5))
plt.ylabel("Energy consumption (Kwh)", fontsize=16)
plt.xlabel("Day", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.savefig(r'../../figures/fuel-consumption-model-electric.png', dpi=400, bbox_inches='tight')
plt.show()
