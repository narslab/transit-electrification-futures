# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df1 = pd.read_csv(r'../../results/fuel-rates-CDB-CHB.csv', delimiter=',', skiprows=0, low_memory=False)

# %%
df1
# Out:
#         time_delta_in_seconds  Unnamed: 0  Unnamed: 0.1      ServiceDateTime  \
# 0                         0.0           0       1062086  2022-04-01 00:00:00
# 1                         0.0           1       1346943  2022-04-01 00:00:08
# 2                         0.0           2       1174966  2022-04-01 00:00:12
# 3                         0.0           3       1213526  2022-04-01 00:00:18
# 4                         0.0           4       1213527  2022-04-01 00:00:18
# ...                       ...         ...           ...                  ...
# 468321                    0.0      475816        243007  2022-04-11 17:45:05
# 468322                   11.0      475817        523373  2022-04-11 17:45:05
# 468323                  682.0      475818        762900  2022-04-11 17:45:05
# 468324                    0.0      475819        762901  2022-04-11 17:45:05
# 468325                   48.0      475820        926794  2022-04-11 17:45:06
#
#         Unnamed: 0.1.1  Unnamed: 0.1.1.1  DateKey             CalendarDate  \
# 0              1062086             46929     8760  2022-04-01 00:00:00.000
# 1              1346943              2437     8760  2022-04-01 00:00:00.000
# 2              1174966             46955     8760  2022-04-01 00:00:00.000
# 3              1213526             48367     8760  2022-04-01 00:00:00.000
# 4              1213527             50425     8760  2022-04-01 00:00:00.000
# ...                ...               ...      ...                      ...
# 468321          243007            453786     8770  2022-04-11 00:00:00.000
# 468322          523373            458754     8770  2022-04-11 00:00:00.000
# 468323          762900            468601     8770  2022-04-11 00:00:00.000
# 468324          762901            468705     8770  2022-04-11 00:00:00.000
# 468325          926794            448001     8770  2022-04-11 00:00:00.000
#
#         Year  Month  ...      time                      geometry      dist  \
# 0       2022      4  ...  00:00:00    POINT (-72.52066 42.35495)  0.000000
# 1       2022      4  ...  00:00:08  POINT (-72.596076 42.342024)  0.000000
# 2       2022      4  ...  00:00:12    POINT (-72.53207 42.32619)  0.000000
# 3       2022      4  ...  00:00:18     POINT (-72.4762 42.35348)  0.000000
# 4       2022      4  ...  00:00:18     POINT (-72.4762 42.35348)  0.000000
# ...      ...    ...  ...       ...                           ...       ...
# 468321  2022      4  ...  17:45:05    POINT (-72.50799 42.08599)  0.219882
# 468322  2022      4  ...  17:45:05    POINT (-72.54151 42.14827)  0.075887
# 468323  2022      4  ...  17:45:05    POINT (-72.60752 42.20827)  0.029317
# 468324  2022      4  ...  17:45:05    POINT (-72.60752 42.20827)  0.000000
# 468325  2022      4  ...  17:45:06    POINT (-72.54912 42.11687)  0.065408
#
#             Speed Acceleration       time_delta    Powertrain  \
# 0        0.000000     0.000000                0             0
# 1        0.000000     0.000000                0        hybrid
# 2        0.000000     0.000000                0             0
# 3        0.000000     0.000000                0             0
# 4        0.000000     0.000000  0 days 00:00:00             0
# ...           ...          ...              ...           ...
# 468321  11.476701    -0.005203  0 days 00:00:00  conventional
# 468322  39.969305    -0.415220  0 days 00:00:11        hybrid
# 468323   0.249048    -0.004500  0 days 00:11:22  conventional
# 468324   0.000000     0.000000  0 days 00:00:00  conventional
# 203790    93.316297     3.441500  0 days 00:00:05  conventional
# 204057   114.883476     3.135706  0 days 00:00:08  conventional
# 252875    93.316297     4.377422  0 days 00:00:05  conventional
# 267456   100.404469     2.771168  0 days 00:00:08        hybrid
# 282400    93.316297     4.052595  0 days 00:00:05        hybrid
# 282632   102.118646     2.376079  0 days 00:00:09        hybrid
# 284508    92.450039    23.485710  0 days 00:00:01  conventional
# 295495    97.593363     4.120402  0 days 00:00:06  conventional
# 303285    89.248417     2.227463  0 days 00:00:09        hybrid
# 317525   122.253219     2.794087  0 days 00:00:04        hybrid
# 328658    93.316297     3.681880  0 days 00:00:05  conventional
# 348785   437.357373   115.547654  0 days 00:00:01  conventional
# 385676  1338.887905   366.432779  0 days 00:00:01  conventional
# 394174    83.964654     4.898797  0 days 00:00:04        hybrid
# 394299    95.077511     2.417709  0 days 00:00:10        hybrid
# 398723    83.964654     5.284492  0 days 00:00:04        hybrid
# 437952    93.316297     4.194052  0 days 00:00:05  conventional
# 446026   100.404469     3.180099  0 days 00:00:08  conventional
# 450499   133.990743     2.723792  0 days 00:00:08  conventional
# 453033    68.145966    18.501409  0 days 00:00:00  conventional
# 458091   117.112036     6.018477  0 days 00:00:05  conventional
#
#                      VehicleModel  Vehicle_mass  FuelRate(L/s)
# 83326         New Flyer 60 hybrid       42250.0      10.701757
# 124083        New Flyer 60 hybrid       42250.0      10.752098
# 127489        New Flyer 60 hybrid       42250.0      11.579200
# 203790  New Flyer 40 conventional       26000.0      10.110091
# 204057  New Flyer 40 conventional       26000.0      12.619902
# 252875  New Flyer 40 conventional       26000.0      15.668458
# 267456        New Flyer 60 hybrid       42250.0      15.576915
# 282400        New Flyer 60 hybrid       42250.0      30.617296
# 282632        New Flyer 60 hybrid       42250.0      13.293111
# 284508        Gillig conventional       26440.0     589.946252
# 295495        Gillig conventional       26440.0      12.238589
# 303285        New Flyer 60 hybrid       42250.0      10.876499
# 317525        New Flyer 60 hybrid       42250.0      23.068953
# 328658        Gillig conventional       26440.0      19.709265
# 348785  New Flyer 40 conventional       26000.0  193766.099426
# 385676  New Flyer 35 conventional           0.0  192210.930706
# 394174        New Flyer 60 hybrid       42250.0      33.212576
# 394299        New Flyer 60 hybrid       42250.0      10.508086
# 398723        New Flyer 60 hybrid       42250.0      39.761173
# 437952  New Flyer 40 conventional       26000.0      13.083892
# 446026  New Flyer 40 conventional       26000.0      10.326969
# 450499        Gillig conventional       26440.0      10.934948
# 453033  New Flyer 40 conventional       26000.0     121.529459
# 458091        Gillig conventional       26440.0      41.886193
#
# [24 rows x 48 columns]

# %%
figure(figsize=(14, 9.5), dpi=400)
plt.plot_date(x=df1['ServiceDateTime']  , y=df1['FuelRate(L/s)'], fmt='o', tz=None, xdate=True, ydate=False, color='teal')
plt.ylabel("FuelRate(L/s)", fontsize=36)
plt.xticks(fontsize=28, rotation = 45)
plt.yticks(fontsize=28)
plt.savefig(r'../../figures/FuelRate-CDB-CHB.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
df_filtered=df1.loc[df1['FuelRate(L/s)']<=10]

# %%
figure(figsize=(14, 9.5), dpi=400)
plt.plot_date(x=df_filtered['ServiceDateTime']  , y=df_filtered['FuelRate(L/s)'], fmt='o', tz=None, xdate=True, ydate=False, color='teal')
plt.ylabel("FuelRate(L/s)", fontsize=36)
plt.xticks(fontsize=28, rotation = 45)
plt.yticks(fontsize=28)
plt.savefig(r'../../figures/FuelRate-filtered-CDB-CHB.png', dpi=400, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30760/4287428348.py in <module>
#       4 plt.xticks(fontsize=28, rotation = 45)
#       5 plt.yticks(fontsize=28)
# ----> 6 plt.savefig(r'../../figures/FuelRate-filtered-CDB-CHB.png', dpi=400, bbox_inches='tight')
#       7 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3017                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3018
# -> 3019             self.canvas.print_figure(fname, **kwargs)
#    3020
#    3021     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2297             if bbox_inches:
#    2298                 if bbox_inches == "tight":
# -> 2299                     bbox_inches = self.figure.get_tightbbox(
#    2300                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2301                     if pad_inches is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1630
#    1631         for a in artists:
# -> 1632             bbox = a.get_tightbbox(renderer)
#    1633             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1634                 bb.append(bbox)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4617             if self.xaxis.get_visible():
#    4618                 try:
# -> 4619                     bb_xaxis = self.xaxis.get_tightbbox(
#    4620                         renderer, for_layout_only=for_layout_only)
#    4621                 except TypeError:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1103         ticks_to_draw = self._update_ticks()
#    1104
# -> 1105         self._update_label_position(renderer)
#    1106
#    1107         # go back to just this axis's tick labels
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2081         # get bounding boxes for this axis and any siblings
#    2082         # that have been set by `fig.align_xlabels()`
# -> 2083         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2084
#    2085         x, y = self.label.get_position()
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_boxes_siblings(self, renderer)
#    1879             axis = getattr(ax, f"{axis_name}axis")
#    1880             ticks_to_draw = axis._update_ticks()
# -> 1881             tlb, tlb2 = axis._get_tick_bboxes(ticks_to_draw, renderer)
#    1882             bboxes.extend(tlb)
#    1883             bboxes2.extend(tlb2)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1083     def _get_tick_bboxes(self, ticks, renderer):
#    1084         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085         return ([tick.label1.get_window_extent(renderer)
#    1086                  for tick in ticks if tick.label1.get_visible()],
#    1087                 [tick.label2.get_window_extent(renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1083     def _get_tick_bboxes(self, ticks, renderer):
#    1084         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085         return ([tick.label1.get_window_extent(renderer)
#    1086                  for tick in ticks if tick.label1.get_visible()],
#    1087                 [tick.label2.get_window_extent(renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     908
#     909         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 910             bbox, info, descent = self._get_layout(self._renderer)
#     911             x, y = self.get_unitless_position()
#     912             x, y = self.get_transform().transform((x, y))
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     307
#     308         # Full vertical extent of font, including ascenders and descenders:
# --> 309         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     310             "lp", self._fontproperties,
#     311             ismath="TeX" if self.get_usetex() else False)
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     268         flags = get_hinting_flag()
#     269         font = self._get_agg_font(prop)
# --> 270         font.set_text(s, 0.0, flags=flags)
#     271         w, h = font.get_width_height()  # width and height of unrotated string
#     272         d = font.get_descent()
#
# KeyboardInterrupt:
