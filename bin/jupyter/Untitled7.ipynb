# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r'../../results/calibration-grid-search-BEB-oct2021-sep2022_01062024.csv', delimiter=',', skiprows=0, low_memory=False)

# %%
df
# Out:
#        Unnamed: 0  parameter1_values  parameter2_values  parameter3_values  \
# 0               0            0.00001               0.90             0.9000
# 1               1            0.00001               0.90             0.9225
# 2               2            0.00001               0.90             0.9450
# 3               3            0.00001               0.90             0.9675
# 4               4            0.00001               0.90             0.9900
# ...           ...                ...                ...                ...
# 12495       12495            1.00000               0.99             0.9000
# 12496       12496            1.00000               0.99             0.9225
# 12497       12497            1.00000               0.99             0.9450
# 12498       12498            1.00000               0.99             0.9675
# 12499       12499            1.00000               0.99             0.9900
#
#        RMSE_Energy_train  MAPE_Energy_train
# ...

# %%
plt.figure(figsize=(10, 6), dpi=400)
plt.plot(df['parameter1_values'], df['MAPE_Energy_train'], marker='o')
plt.title('MAPE_Energy_train vs gamma Values')
plt.xlabel('Gamma values')
plt.ylabel('MAPE energy train')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=400)
plt.plot(df['parameter2_values'], df['MAPE_Energy_train'], marker='o')
plt.title('MAPE_Energy_train vs eta_m Values')
plt.xlabel('eta_m values')
plt.ylabel('MAPE energy train')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=400)
plt.plot(df['parameter3_values'], df['MAPE_Energy_train'], marker='o')
plt.title('MAPE_Energy_train vs eta_d Values')
plt.xlabel('eta_d values')
plt.ylabel('MAPE energy train')
plt.grid(True)
plt.show()
