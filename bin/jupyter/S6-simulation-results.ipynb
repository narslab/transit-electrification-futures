# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
SQ =pd.read_csv(r'../../results/computed-fuel-rates-oct2021-sep2022.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
year_one_S6 =pd.read_csv(r'../../results/computed-fuel-rates-S6-2023.0.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
year_two_S6 =pd.read_csv(r'../../results/computed-fuel-rates-S6-2024.0.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
year_three_S6 =pd.read_csv(r'../../results/computed-fuel-rates-S6-2025.0.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
year_four_S6 =pd.read_csv(r'../../results/computed-fuel-rates-S6-2026.0.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
year_five_S6 =pd.read_csv(r'../../results/computed-fuel-rates-S6-2027.0.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
year_six_S6 =pd.read_csv(r'../../results/computed-fuel-rates-S6-2028.0.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
diesel_SQ=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()*6

# %%
diesel_S6=year_one_S6['Energy'].loc[year_one_S6['Powertrain']!='electric'].sum()+year_two_S6['Energy'].loc[year_two_S6['Powertrain']!='electric'].sum()+year_three_S6['Energy'].loc[year_three_S6['Powertrain']!='electric'].sum()+year_four_S6['Energy'].loc[year_four_S6['Powertrain']!='electric'].sum()+year_five_S6['Energy'].loc[year_five_S6['Powertrain']!='electric'].sum()+year_six_S6['Energy'].loc[year_six_S6['Powertrain']!='electric'].sum()

# %%
diesel_SQ
# Out:
# 11230685.170879247

# %%
diesel_S6
# Out:
# 4765735.847171468

# %%
diesel_S6/diesel_SQ
# Out:
# 0.42434951872115917

# %%
diesel_SQ_2023=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2024=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2025=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2026=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2027=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2028=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2029=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2030=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2031=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2032=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2033=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2034=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_SQ_2035=SQ['Energy'].loc[SQ['Powertrain']!='electric'].sum()
diesel_S6_2023=year_one_S6['Energy'].loc[year_one_S6['Powertrain']!='electric'].sum()
diesel_S6_2024=year_two_S6['Energy'].loc[year_two_S6['Powertrain']!='electric'].sum()
diesel_S6_2025=year_three_S6['Energy'].loc[year_three_S6['Powertrain']!='electric'].sum()
diesel_S6_2026=year_four_S6['Energy'].loc[year_four_S6['Powertrain']!='electric'].sum()
diesel_S6_2027=year_five_S6['Energy'].loc[year_five_S6['Powertrain']!='electric'].sum()
diesel_S6_2028=year_six_S6['Energy'].loc[year_six_S6['Powertrain']!='electric'].sum()
diesel_S6_2029=year_six_S6['Energy'].loc[year_six_S6['Powertrain']!='electric'].sum()
diesel_S6_2030=year_six_S6['Energy'].loc[year_six_S6['Powertrain']!='electric'].sum()
diesel_S6_2031=year_six_S6['Energy'].loc[year_six_S6['Powertrain']!='electric'].sum()
diesel_S6_2032=year_six_S6['Energy'].loc[year_six_S6['Powertrain']!='electric'].sum()
diesel_S6_2033=year_six_S6['Energy'].loc[year_six_S6['Powertrain']!='electric'].sum()
diesel_S6_2034=year_six_S6['Energy'].loc[year_six_S6['Powertrain']!='electric'].sum()
diesel_S6_2035=year_six_S6['Energy'].loc[year_six_S6['Powertrain']!='electric'].sum()

# %%
import matplotlib.pyplot as plt
import numpy as np

# list to hold the years
years = list(range(2023, 2036))

# list to hold the values of diesel_SQ for each year
diesel_SQ = [
    diesel_SQ_2023,
    diesel_SQ_2024,
    diesel_SQ_2025,
    diesel_SQ_2026,
    diesel_SQ_2027,
    diesel_SQ_2028,
    diesel_SQ_2029,
    diesel_SQ_2030,
    diesel_SQ_2031,
    diesel_SQ_2032,
    diesel_SQ_2033,
    diesel_SQ_2034,
    diesel_SQ_2035,
]

# list to hold the values of diesel_S6 for each year
diesel_S6 = [
    diesel_S6_2023,
    diesel_S6_2024,
    diesel_S6_2025,
    diesel_S6_2026,
    diesel_S6_2027,
    diesel_S6_2028,
    diesel_S6_2029,
    diesel_S6_2030,
    diesel_S6_2031,
    diesel_S6_2032,
    diesel_S6_2033,
    diesel_S6_2034,
    diesel_S6_2035,
]

barWidth = 0.35  # the width of the bars

# Set position of bar on X axis
r1 = np.arange(len(diesel_SQ)) 
r2 = [x + barWidth for x in r1]

# create a new figure and a subplot
fig, ax = plt.subplots(figsize=(12,8), dpi=400)

# plot diesel_SQ with color lightcoral
ax.bar(r1, diesel_SQ, color='lightcoral', width=barWidth, edgecolor='grey', label='SQ')

# plot diesel_S6 with color lightgreen
ax.bar(r2, diesel_S6, color='lightgreen', width=barWidth, edgecolor='grey', label='S6')

# calculate the means
mean_SQ = np.mean(diesel_SQ)
mean_S6 = np.mean(diesel_S6)

# plot lines for the mean values
#ax.axhline(mean_SQ, color='lightcoral', linestyle='--', label='Mean SQ')
ax.axhline(mean_S6, color='lightgreen', linestyle='--', label='Mean S6')

# set the title and labels
#ax.set_title('Diesel SQ and S6 comparison per year')
ax.set_xlabel('Years', fontsize=14)
ax.set_ylabel('Yearly diesel consumption (gal)', fontsize=14)

# increase the font size of x-axis and y-axis tick labels
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)

# add a legend with increased font size
ax.legend(fontsize=14)

# display the plot
plt.show()

# Saving
fig.savefig(r'../../figures/electrification-strategies.png', dpi=300, bbox_inches='tight')

# %%
hybrid_diesel_consumption=SQ['Energy'].loc[SQ['Powertrain']=='hybrid'].sum()
hybrid_vehicles = SQ.loc[SQ['Powertrain'] == 'hybrid', 'Vehicle']
unique_hybrid_count = hybrid_vehicles.nunique()
#hybrid_diesel_consumption
#unique_hybrid_count
mean_hybrid_diesel_consumption=hybrid_diesel_consumption/unique_hybrid_count
mean_hybrid_diesel_consumption
# Out:
# 3981.587511574421

# %%
conventional_diesel_consumption=SQ['Energy'].loc[SQ['Powertrain']=='conventional'].sum()
conventional_vehicles = SQ.loc[SQ['Powertrain'] == 'conventional', 'Vehicle']
unique_conventional_count = conventional_vehicles.nunique()
#conventional_diesel_consumption
#unique_conventional_count
mean_conventional_diesel_consumption=conventional_diesel_consumption/unique_conventional_count
mean_conventional_diesel_consumption
# Out:
# 9714.00303814307

# %%
year_one_S2 =pd.read_csv(r'../../results/computed-fuel-rates-S2-2023.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
year_two_S2 =pd.read_csv(r'../../results/computed-fuel-rates-S2-2024.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
year_three_S2 =pd.read_csv(r'../../results/computed-fuel-rates-S2-2025.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
diesel_S2_2023=year_one_S2['Energy'].loc[year_one_S2['Powertrain']!='electric'].sum()
diesel_S2_2024=year_two_S2['Energy'].loc[year_two_S2['Powertrain']!='electric'].sum()
diesel_S2_2025=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2026=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2027=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2028=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2029=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2030=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2031=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2032=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2033=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2034=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()
diesel_S2_2035=year_three_S2['Energy'].loc[year_three_S2['Powertrain']!='electric'].sum()

# %%
import matplotlib.pyplot as plt
import numpy as np

# list to hold the years
years = list(range(2023, 2036))

# list to hold the values of diesel_SQ for each year
diesel_SQ = [
    diesel_SQ_2023,
    diesel_SQ_2024,
    diesel_SQ_2025,
    diesel_SQ_2026,
    diesel_SQ_2027,
    diesel_SQ_2028,
    diesel_SQ_2029,
    diesel_SQ_2030,
    diesel_SQ_2031,
    diesel_SQ_2032,
    diesel_SQ_2033,
    diesel_SQ_2034,
    diesel_SQ_2035,
]

# list to hold the values of diesel_S6 for each year
diesel_S6 = [
    diesel_S6_2023,
    diesel_S6_2024,
    diesel_S6_2025,
    diesel_S6_2026,
    diesel_S6_2027,
    diesel_S6_2028,
    diesel_S6_2029,
    diesel_S6_2030,
    diesel_S6_2031,
    diesel_S6_2032,
    diesel_S6_2033,
    diesel_S6_2034,
    diesel_S6_2035,
]

# list to hold the values of diesel_S2 for each year
diesel_S2 = [
    diesel_S2_2023,
    diesel_S2_2024,
    diesel_S2_2025,
    diesel_S2_2026,
    diesel_S2_2027,
    diesel_S2_2028,
    diesel_S2_2029,
    diesel_S2_2030,
    diesel_S2_2031,
    diesel_S2_2032,
    diesel_S2_2033,
    diesel_S2_2034,
    diesel_S2_2035,
]


barWidth = 0.35  # the width of the bars

# Set position of bar on X axis
r1 = np.arange(len(diesel_SQ)) 
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

# create a new figure and a subplot
fig, ax = plt.subplots(figsize=(12,8), dpi=400)

# plot diesel_SQ with color lightcoral
ax.bar(r1, diesel_SQ, color='lightcoral', width=barWidth, edgecolor='grey', label='SQ')

# plot diesel_S6 with color lightgreen
ax.bar(r2, diesel_S6, color='lightgreen', width=barWidth, edgecolor='grey', label='S6')

# plot diesel_S6 with color lightgreen
ax.bar(r3, diesel_S2, color='steelblue', width=barWidth, edgecolor='grey', label='S2')

# calculate the means
mean_SQ = np.mean(diesel_SQ)
mean_S6 = np.mean(diesel_S6)
mean_S2 = np.mean(diesel_S2)


# plot lines for the mean values
#ax.axhline(mean_SQ, color='lightcoral', linestyle='--', label='Mean SQ')
ax.axhline(mean_S6, color='lightgreen', linestyle='--', label='Mean S6')
ax.axhline(mean_S2, color='steelblue', linestyle='--', label='Mean S2')


# set the title and labels
#ax.set_title('Diesel SQ and S6 comparison per year')
ax.set_xlabel('Years', fontsize=14)
ax.set_ylabel('Yearly diesel consumption (gal)', fontsize=14)

# increase the font size of x-axis and y-axis tick labels
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)

# add a legend with increased font size
ax.legend(fontsize=14)

# display the plot
plt.show()

# Saving
fig.savefig(r'../../figures/electrification-strategies.png', dpi=300, bbox_inches='tight')

# %%
SQ_total=sum(diesel_SQ)
S2_total=sum(diesel_S2)
S6_total=sum(diesel_S6)

# %%
S6_total/SQ_total
# Out:
# 0.39295624821377234

# %%
S2_total/SQ_total
# Out:
# 0.8814294111112794

# %%
year_one_S3 =pd.read_csv(r'../../results/computed-fuel-rates-S3-2023.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
year_two_S3 =pd.read_csv(r'../../results/computed-fuel-rates-S3-2024.csv', usecols=['ServiceDateTime', 'Month', 'Route','Vehicle','Powertrain','VehicleModel','Energy'], delimiter=',', skiprows=0, low_memory=False)

# %%
diesel_S3_2023=year_one_S3['Energy'].loc[year_one_S3['Powertrain']!='electric'].sum()
diesel_S3_2024=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2025=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2026=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2027=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2028=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2029=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2030=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2031=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2032=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2033=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2034=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()
diesel_S3_2035=year_two_S3['Energy'].loc[year_two_S3['Powertrain']!='electric'].sum()

# %%
import matplotlib.pyplot as plt
import numpy as np

# list to hold the years
years = list(range(2023, 2036))

# list to hold the values of diesel_SQ for each year
diesel_SQ = [
    diesel_SQ_2023,
    diesel_SQ_2024,
    diesel_SQ_2025,
    diesel_SQ_2026,
    diesel_SQ_2027,
    diesel_SQ_2028,
    diesel_SQ_2029,
    diesel_SQ_2030,
    diesel_SQ_2031,
    diesel_SQ_2032,
    diesel_SQ_2033,
    diesel_SQ_2034,
    diesel_SQ_2035,
]

# list to hold the values of diesel_S6 for each year
diesel_S6 = [
    diesel_S6_2023,
    diesel_S6_2024,
    diesel_S6_2025,
    diesel_S6_2026,
    diesel_S6_2027,
    diesel_S6_2028,
    diesel_S6_2029,
    diesel_S6_2030,
    diesel_S6_2031,
    diesel_S6_2032,
    diesel_S6_2033,
    diesel_S6_2034,
    diesel_S6_2035,
]

# list to hold the values of diesel_S2 for each year
diesel_S2 = [
    diesel_S2_2023,
    diesel_S2_2024,
    diesel_S2_2025,
    diesel_S2_2026,
    diesel_S2_2027,
    diesel_S2_2028,
    diesel_S2_2029,
    diesel_S2_2030,
    diesel_S2_2031,
    diesel_S2_2032,
    diesel_S2_2033,
    diesel_S2_2034,
    diesel_S2_2035,
]

# list to hold the values of diesel_S3 for each year
diesel_S3 = [
    diesel_S3_2023,
    diesel_S3_2024,
    diesel_S3_2025,
    diesel_S3_2026,
    diesel_S3_2027,
    diesel_S3_2028,
    diesel_S3_2029,
    diesel_S3_2030,
    diesel_S3_2031,
    diesel_S3_2032,
    diesel_S3_2033,
    diesel_S3_2034,
    diesel_S3_2035,
]

barWidth = 0.35  # the width of the bars

# Set position of bar on X axis
r1 = np.arange(len(diesel_SQ)) 
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]


# create a new figure and a subplot
fig, ax = plt.subplots(figsize=(12,8), dpi=400)

# plot diesel_SQ with color lightcoral
ax.plot(diesel_SQ, color='lightcoral', label='S1')

# plot diesel_S6 with color lightgreen
ax.plot(diesel_S6, color='lightgreen', label='S6')

# plot diesel_S2 with color steelblue
ax.plot(diesel_S2, color='steelblue',label='S2')

# plot diesel_S3 with color steelblue
#ax.plot(diesel_S3, color='green', label='S3')

# calculate the means
mean_SQ = np.mean(diesel_SQ)
mean_S6 = np.mean(diesel_S6)
mean_S2 = np.mean(diesel_S2)
mean_S3 = np.mean(diesel_S3)



# plot lines for the mean values
#ax.axhline(mean_SQ, color='lightcoral', linestyle='--', label='Mean SQ')
#ax.axhline(mean_S6, color='lightgreen', linestyle='--', label='Mean S6')
#ax.axhline(mean_S2, color='steelblue', linestyle='--', label='Mean S2')
#ax.axhline(mean_S3, color='green', linestyle='--', label='Mean S2')



# set the title and labels
#ax.set_title('Diesel SQ and S6 comparison per year')
ax.set_xlabel('Years', fontsize=18)
ax.set_ylabel('Yearly diesel consumption (gal)', fontsize=18)

# increase the font size of x-axis and y-axis tick labels
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)

# add a legend with increased font size
ax.legend(fontsize=18)
#ax.set_title('Yearly diesel consumption by strategy', fontsize=18)


# display the plot
plt.show()

# Saving
fig.savefig(r'../../figures/electrification-strategies.png', dpi=300, bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate the total diesel consumption
sum_SQ = np.sum(diesel_SQ)
sum_S6 = np.sum(diesel_S6)
sum_S2 = np.sum(diesel_S2)
#sum_S3 = np.sum(diesel_S3)

# Put the sums into a list
sums = [sum_SQ, sum_S2, sum_S6]

# Corresponding labels
labels = ['S1', 'S2', 'S6']

# Corresponding colors
colors = ['lightcoral', 'lightgreen', 'steelblue']

# Create a new figure and a subplot
fig, ax = plt.subplots(figsize=(12, 8), dpi=400)

# Create a bar plot
ax.bar(labels, sums, color=colors)

# Adding labels and title
ax.set_ylabel('Total diesel consumption (gal)', fontsize=18)
ax.set_xlabel('Strategies', fontsize=18)
#ax.set_title('Total diesel consumption by strategy', fontsize=18)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)

# Show the plot
plt.show()

# Saving the plot
fig.savefig(r'../../figures/electrification-strategies-total.png', dpi=300, bbox_inches='tight')

# %%
SQ_total=sum(diesel_SQ)
S2_total=sum(diesel_S2)
S3_total=sum(diesel_S3)
S6_total=sum(diesel_S6)

# %%
S2_total/SQ_total
# Out:
# 0.8814294111112794

# %%
S3_total/SQ_total
# Out:
# 0.8960384568227278

# %%
S6_total/SQ_total
# Out:
# 0.39295624821377234

# %%
# Count unique vehicles for each powertrain category
unique_vehicles = year_one_S3.groupby('Powertrain')['Vehicle'].nunique()

# Compute proportions
total = unique_vehicles.sum()
percentages = unique_vehicles / total * 100

# Display the results
print("Count of unique vehicles for each powertrain category:")
print(unique_vehicles)
print("\nProportions:")
print(percentages)
# Out:
# Count of unique vehicles for each powertrain category:
# Powertrain
# conventional    123
# electric         15
# hybrid           75
# Name: Vehicle, dtype: int64
#
# Proportions:
# Powertrain
# conventional    57.746479
# electric         7.042254
# hybrid          35.211268
# Name: Vehicle, dtype: float64

# %%
percentages
# Out:
# Powertrain
# conventional    57.746479
# electric         7.042254
# hybrid          35.211268
# Name: Vehicle, dtype: float64

# %%
year_1_SQ=SQ
year_2_SQ=SQ
year_3_SQ=SQ
year_4_SQ=SQ
year_5_SQ=SQ
year_6_SQ=SQ
year_7_SQ=SQ
year_8_SQ=SQ
year_9_SQ=SQ
year_10_SQ=SQ
year_11_SQ=SQ
year_12_SQ=SQ
year_13_SQ=SQ
year_1_S6=year_one_S6
year_2_S6=year_two_S6
year_3_S6=year_three_S6
year_4_S6=year_four_S6
year_5_S6=year_five_S6
year_6_S6=year_six_S6
year_7_S6=year_six_S6
year_8_S6=year_six_S6
year_9_S6=year_six_S6
year_10_S6=year_six_S6
year_11_S6=year_six_S6
year_12_S6=year_six_S6
year_13_S6=year_six_S6
year_1_S2=year_one_S2
year_2_S2=year_two_S2
year_3_S2=year_three_S2
year_4_S2=year_three_S2
year_5_S2=year_three_S2
year_6_S2=year_three_S2
year_7_S2=year_three_S2
year_8_S2=year_three_S2
year_9_S2=year_three_S2
year_10_S2=year_three_S2
year_11_S2=year_three_S2
year_12_S2=year_three_S2
year_13_S2=year_three_S2


# Define a function to calculate the percentage of electric vehicles
def calc_electric_percentage(df):
    unique_vehicles = df.groupby(['Year', 'Powertrain'])['Vehicle'].nunique()
    total_vehicles = df.groupby('Year')['Vehicle'].nunique()
    percentages = (unique_vehicles / total_vehicles * 100).reset_index()
    return percentages[percentages['Powertrain'] == 'electric']

# Combine the DataFrames for each year and each strategy, and add a 'Year' column
strategies = ['SQ', 'S2', 'S6']
dataframes = {strategy: pd.concat([eval(f"year_{i}_{strategy}").assign(Year=i) for i in range(1, 14)]) for strategy in strategies}

# Calculate the percentages for each strategy
percentages = {strategy: calc_electric_percentage(df) for strategy, df in dataframes.items()}

# Merge the percentages into a single DataFrame
merged_percentages = pd.concat([df.assign(Strategy=strategy) for strategy, df in percentages.items()])

# Pivot the DataFrame to have one column per strategy
pivoted_percentages = merged_percentages.pivot(index='Year', columns='Strategy', values='Vehicle')

# Plot the percentages
pivoted_percentages.plot(kind='line')

# Set the labels and title
plt.ylabel('% Electric Vehicles')
plt.title('% Electric Vehicles Over Time for Different Strategies')

# Show the plot
plt.show()

# %%
# replace all occurrences of '(X)' with an empty string
SQ['Route'] = SQ['Route'].str.replace(r'\(X\)|\(\)', '', regex=True)
SQ['Route'] = SQ['Route'].str.lstrip()
SQ=SQ.loc[SQ['Route']!='9999']

# %%
SQ['Route'].unique()
# Out:
# array(['R44', '39E', 'B48', '801', '806', 'B6', 'R14', 'X92', 'G73',
#        'X90', '821', '820', 'P11', '804', '805', '824', '823', '802',
#        '892', '803', 'R24', 'B17', 'R10', 'G3', 'B4', 'B7', 'R29', 'B23',
#        'P20', 'G5', 'G1', 'B12', 'G2', '921', 'P21', '902', '890', 'B9',
#        'R42', 'R41', 'B79', '38', '30', '31', '33', '46', '45', '36',
#        '35', '34', 'B43', '943'], dtype=object)

# %%
# replace all occurrences of '(X)' with an empty string
year_six_S6['Route'] = year_six_S6['Route'].str.replace(r'\(X\)|\(\)', '', regex=True)
year_six_S6['Route'] = year_six_S6['Route'].str.lstrip()
year_six_S6=year_six_S6.loc[year_six_S6['Route']!='9999']

# %%
# replace all occurrences of '(X)' with an empty string
year_three_S2['Route'] = year_three_S2['Route'].str.replace(r'\(X\)|\(\)', '', regex=True)
year_three_S2['Route'] = year_three_S2['Route'].str.lstrip()
year_three_S2=year_three_S2.loc[year_three_S2['Route']!='9999']

# %%
# Define a function to calculate the percentage of electric vehicles, hybrid vehicles, and conventional vehicles
def calc_powertrain_percentage_route(df, powertrain):
    unique_vehicles = df.groupby(['Route', 'Powertrain'])['Vehicle'].nunique()
    total_vehicles = df.groupby('Route')['Vehicle'].nunique()
    percentages = (unique_vehicles / total_vehicles * 100).reset_index()
    return percentages[percentages['Powertrain'] == powertrain]

# %%
# Calculate the percentages for the SQ strategy in year one
percentages_electric_SQ_route = calc_powertrain_percentage_route(SQ, 'electric')
percentages_hybrid_SQ_route = calc_powertrain_percentage_route(SQ, 'hybrid')
percentages_conventional_SQ_route = calc_powertrain_percentage_route(SQ, 'conventional')

# Create a list of all unique route names
all_routes = set(percentages_electric_SQ_route['Route']).union(
    set(percentages_hybrid_SQ_route['Route']),
    set(percentages_conventional_SQ_route['Route'])
)

# Convert the list to a dataframe
df_all_routes = pd.DataFrame(list(all_routes), columns=['Route'])

# Merge the dataframes on 'Route'
df_merge = df_all_routes.merge(percentages_electric_SQ_route, on='Route', how='left').merge(
    percentages_hybrid_SQ_route, on='Route', how='left').merge(
    percentages_conventional_SQ_route, on='Route', how='left')

# Replace any NaN values with 0
df_merge.fillna(0, inplace=True)

# Data manipulation for the bar chart
df_conventional = df_merge[['Route', 'Powertrain', 'Vehicle']].where(df_merge['Powertrain'] == 'conventional').dropna()
df_hybrid = df_merge[['Route', 'Powertrain_x', 'Vehicle_x']].where(df_merge['Powertrain_x'] == 'hybrid').dropna().rename(columns={'Powertrain_x': 'Powertrain', 'Vehicle_x': 'Vehicle'})
df_electric = df_merge[['Route', 'Powertrain_y', 'Vehicle_y']].where(df_merge['Powertrain_y'] == 'electric').dropna().rename(columns={'Powertrain_y': 'Powertrain', 'Vehicle_y': 'Vehicle'})

# Merging them back into one dataframe
df_merge = df_conventional.merge(df_hybrid, on='Route', how='outer', suffixes=('_conventional', '_hybrid'))
df_merge = df_final.merge(df_electric, on='Route', how='outer')
df_merge = df_final.rename(columns={'Vehicle': 'Vehicle_electric'}).fillna(0)



# Plot the percentages
fig, ax = plt.subplots(figsize=(30, 8), dpi=400)

# Plot stacked bars
# Conventionals at the bottom
df_merge.plot(x='Route', y='conventional', kind='bar', legend=False, color='lightcoral', ax=ax)
# Then stack hybrids on top
df_merge.plot(x='Route', y='Hybrid', kind='bar', legend=False, color='steelblue', bottom=df_merge['conventional'], ax=ax)
# Finally, stack electrics on top
df_merge.plot(x='Route', y='Electric', kind='bar', legend=False, color='mediumseagreen', bottom=df_merge['conventional'] + df_merge['Hybrid'], ax=ax)

# Set the labels and title
ax.set_ylabel('Electrification%', fontsize=32)
ax.set_xlabel('')
ax.set_title('% Vehicles by Route for SQ Strategy in Year 2028', fontsize=36)
ax.tick_params(axis='x', labelsize=28)
ax.tick_params(axis='y', labelsize=28)

# Add a legend
ax.legend(["Conventional", "Hybrid", "Electric"], loc='upper left', fontsize=20)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 30>()
#      28 # Merging them back into one dataframe
#      29 df_merge = df_conventional.merge(df_hybrid, on='Route', how='outer', suffixes=('_conventional', '_hybrid'))
# ---> 30 df_merge = df_final.merge(df_electric, on='Route', how='outer')
#      31 df_merge = df_final.rename(columns={'Vehicle': 'Vehicle_electric'}).fillna(0)
#      35 # Plot the percentages
#
# NameError: name 'df_final' is not defined

# %%
# Calculate the percentages for the SQ strategy in year 2028
percentages_S2_route = calc_electric_percentage_route(year_three_S2)

# Plot the percentages
fig, ax = plt.subplots(figsize=(30, 8), dpi=400)
percentages_S2_route.plot(x='Route', y='Vehicle', kind='bar', legend=False, color='mediumseagreen', ax=ax)

# Set the labels and title
ax.set_ylabel('Electrification%', fontsize=32)
ax.set_xlabel('')
ax.set_title('% Electric Vehicles by Route for S2 Strategy in Year 2028', fontsize=36)
ax.tick_params(axis='x', labelsize=28)
ax.tick_params(axis='y', labelsize=28)

# Show the plot
plt.show()

# %%
# Calculate the percentages for the SQ strategy in year 2028
percentages_S6_route = calc_electric_percentage_route(year_six_S6)

# Plot the percentages
fig, ax = plt.subplots(figsize=(30, 8), dpi=400)
percentages_S6_route.plot(x='Route', y='Vehicle', kind='bar', legend=False, color='mediumseagreen', ax=ax)

# Set the labels and title
ax.set_ylabel('Electrification%', fontsize=32)
ax.set_xlabel('')
ax.set_title('% Electric Vehicles by Route for S6 Strategy in Year 2028', fontsize=36)
ax.tick_params(axis='x', labelsize=28)
ax.tick_params(axis='y', labelsize=28)

# Show the plot
plt.show()

# %%
df_merge
# Out:
#    Route Powertrain_x  Vehicle_x Powertrain_y  Vehicle_y    Powertrain  \
# 0    P20     electric   6.060606       hybrid   3.787879  conventional
# 1    X90     electric   6.481481       hybrid   2.777778  conventional
# 2    R10     electric   6.474820       hybrid   3.597122  conventional
# 3    821     electric   8.965517       hybrid   3.448276  conventional
# 4     35            0   0.000000            0   0.000000  conventional
# 5     45     electric   2.702703            0   0.000000  conventional
# 6    B23     electric   3.125000       hybrid   3.125000  conventional
# 7    921     electric   9.000000       hybrid   5.000000  conventional
# 8     G5     electric   6.201550       hybrid   3.100775  conventional
# 9    943     electric   5.882353       hybrid  11.764706  conventional
# 10    B9            0   0.000000       hybrid   1.449275  conventional
# 11   892     electric  10.576923       hybrid   4.807692  conventional
# ...
