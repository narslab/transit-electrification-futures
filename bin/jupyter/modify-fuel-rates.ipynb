# %%
import pandas as pd

# %%
df_final = pd.read_csv(r'../../results/computed-fuel-rates.csv', delimiter=',', skiprows=0, low_memory=False)

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0.4', 'Unnamed: 0.3', 'Unnamed: 0.2', 'ServiceDateTime',
#        'Unnamed: 0', 'Unnamed: 0.1', 'DateKey', 'CalendarDate', 'Year',
#        'Month', 'OpKey', 'Operator', 'RtKey', 'RtKey2', 'Route', 'RouteName',
#        'TripKey', 'Trip', 'StopKey', 'Stop', 'StopName', 'Lat', 'Lon',
#        'Vehicle', 'VehicleType', 'SeatedCap', 'TotalCap', 'Boards', 'Alights',
#        'Onboard', 'Bike', 'Wheelchair', 'Weekday', 'Hour', 'Minute', 'Second',
#        'Date', 'Daytype', 'time', 'geometry', 'dist', 'Speed', 'Acceleration',
#        'time_delta', 'time_delta_in_seconds', 'Powertrain', 'VehicleModel',
#        'Vehicle_mass', 'Energy'],
#       dtype='object')

# %%
len(df_final['Vehicle'].unique())
# Out:
# 178

# %%
df_final.Vehicle_mass
# Out:
# 0          26900.0
# 1          26900.0
# 2          26900.0
# 3          26900.0
# 4          26900.0
#             ...
# 1361544    26900.0
# 1361545    26900.0
# 1361546    26900.0
# 1361547    26900.0
# 1361548    26900.0
# Name: Vehicle_mass, Length: 1361549, dtype: float64

# %%
zeros = df_final[df_final['Energy'] == 0]
zeros
# Out:
#          Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2      ServiceDateTime  \
# 0              112024        112024             0  2022-04-04 06:43:24
# 1              112500        112500             1  2022-04-04 06:51:27
# 2              112501        112501             2  2022-04-04 06:51:27
# 16             114379        114379            16  2022-04-04 07:20:47
# 32             116181        116181            33  2022-04-04 07:52:30
# ...               ...           ...           ...                  ...
# 1361450       1360727       1360727       1361449  2022-04-30 21:34:29
# 1361479       1361035       1361035       1361479  2022-04-30 22:17:02
# 1361507       1361258       1361258       1361508  2022-04-30 23:00:30
# 1361508       1361259       1361259       1361507  2022-04-30 23:00:30
# 1361537       1361463       1361463       1361537  2022-04-30 23:42:14
#
#          Unnamed: 0  Unnamed: 0.1  DateKey             CalendarDate  Year  \
# ...

# %%
df_final.sort_values(by=['Vehicle','ServiceDateTime'], ascending=True, inplace=True)

# %%
df_final
# Out:
#          Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2      ServiceDateTime  \
# 0              112024        112024             0  2022-04-04 06:43:24
# 1              112500        112500             1  2022-04-04 06:51:27
# 2              112501        112501             2  2022-04-04 06:51:27
# 3              112584        112584             3  2022-04-04 06:52:52
# 4              112675        112675             4  2022-04-04 06:54:33
# ...               ...           ...           ...                  ...
# 1361544       1361526       1361526       1361544  2022-04-30 23:54:20
# 1361545       1361530       1361530       1361545  2022-04-30 23:55:24
# 1361546       1361539       1361539       1361546  2022-04-30 23:56:47
# 1361547       1361541       1361541       1361547  2022-04-30 23:57:32
# 1361548       1361546       1361546       1361548  2022-04-30 23:59:29
#
#          Unnamed: 0  Unnamed: 0.1  DateKey             CalendarDate  Year  \
# ...

# %%
for i in df_final.index:
    if i==0:
        df_final.at[i , 'Energy'] = 0
    elif df_final['Vehicle_mass'].loc[i]==0:
        df_final.at[i , 'Energy'] = 0
    else:
        if df_final['Vehicle'].loc[i]==df_final['Vehicle'].loc[i-1]:
            if df_final['Date'].loc[i]!=df_final['Date'].loc[i-1]:
                df_final.at[i , 'Energy'] = 0
        else:
            df_final.at[i , 'Energy'] = 0

# %%
df_final
# Out:
#          Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2      ServiceDateTime  \
# 0              112024        112024             0  2022-04-04 06:43:24
# 1              112500        112500             1  2022-04-04 06:51:27
# 2              112501        112501             2  2022-04-04 06:51:27
# 3              112584        112584             3  2022-04-04 06:52:52
# 4              112675        112675             4  2022-04-04 06:54:33
# ...               ...           ...           ...                  ...
# 1361544       1361526       1361526       1361544  2022-04-30 23:54:20
# 1361545       1361530       1361530       1361545  2022-04-30 23:55:24
# 1361546       1361539       1361539       1361546  2022-04-30 23:56:47
# 1361547       1361541       1361541       1361547  2022-04-30 23:57:32
# 1361548       1361546       1361546       1361548  2022-04-30 23:59:29
#
#          Unnamed: 0  Unnamed: 0.1  DateKey             CalendarDate  Year  \
# ...

# %%
zeros = df_final[df_final['Energy'] == 0]
zeros
# Out:
#          Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.